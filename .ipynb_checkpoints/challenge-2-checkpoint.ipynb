# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources in the README.md file
# - Happy learning!

# %%
# Import your libraries:

# %matplotlib inline

import numpy as np
import pandas as pd

# %% [markdown]
# In this lab, we will explore a dataset that describes websites with different features and labels them either benign or malicious . We will use supervised learning algorithms to figure out what feature patterns malicious websites are likely to have and use our model to predict malicious websites.
#
# # Challenge 1 - Explore The Dataset
#
# Let's start by exploring the dataset. First load the data file:

# %%
websites = pd.read_csv('data/website.csv')

# %% [markdown]
# #### Explore the data from an bird's-eye view.
#
# You should already been very familiar with the procedures now so we won't provide the instructions step by step. Reflect on what you did in the previous labs and explore the dataset.
#
# Things you'll be looking for:
#
# * What the dataset looks like?
# * What are the data types?
# * Which columns contain the features of the websites?
# * Which column contains the feature we will predict? What is the code standing for benign vs malicious websites?
# * Do we need to transform any of the columns from categorical to ordinal values? If so what are these columns?
#
# Feel free to add additional cells for your explorations. Make sure to comment what you find out.

# %%
# Show the first 5 rows of the dataset
websites.head()
# Out:
#        URL  URL_LENGTH  NUMBER_SPECIAL_CHARACTERS     CHARSET  \
# 0   M0_109          16                          7  iso-8859-1
# 1  B0_2314          16                          6       UTF-8
# 2   B0_911          16                          6    us-ascii
# 3   B0_113          17                          6  ISO-8859-1
# 4   B0_403          17                          6       UTF-8
#
#                   SERVER  CONTENT_LENGTH WHOIS_COUNTRY WHOIS_STATEPRO  \
# 0                  nginx           263.0           NaN            NaN
# 1          Apache/2.4.10         15087.0           NaN            NaN
# 2  Microsoft-HTTPAPI/2.0           324.0           NaN            NaN
# 3                  nginx           162.0            US             AK
# 4                    NaN        124140.0            US             TX
#
#       WHOIS_REGDATE WHOIS_UPDATED_DATE  ...  DIST_REMOTE_TCP_PORT  REMOTE_IPS  \
# 0  10/10/2015 18:21                NaN  ...                     0           2
# ...

# %%
# Show basic info about columns and data types
websites.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1781 entries, 0 to 1780
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   URL                        1781 non-null   object
#  1   URL_LENGTH                 1781 non-null   int64
#  2   NUMBER_SPECIAL_CHARACTERS  1781 non-null   int64
#  3   CHARSET                    1774 non-null   object
#  4   SERVER                     1605 non-null   object
#  5   CONTENT_LENGTH             969 non-null    float64
#  6   WHOIS_COUNTRY              1475 non-null   object
#  7   WHOIS_STATEPRO             1419 non-null   object
#  8   WHOIS_REGDATE              1654 non-null   object
#  9   WHOIS_UPDATED_DATE         1642 non-null   object
#  10  TCP_CONVERSATION_EXCHANGE  1781 non-null   int64
#  11  DIST_REMOTE_TCP_PORT       1781 non-null   int64
#  12  REMOTE_IPS                 1781 non-null   int64
# ...

# %%
# Show summary statistics for numerical columns
websites.describe()
# Out:
#         URL_LENGTH  NUMBER_SPECIAL_CHARACTERS  CONTENT_LENGTH  \
# count  1781.000000                1781.000000      969.000000
# mean     56.961258                  11.111735    11726.927761
# std      27.555586                   4.549896    36391.809051
# min      16.000000                   5.000000        0.000000
# 25%      39.000000                   8.000000      324.000000
# 50%      49.000000                  10.000000     1853.000000
# 75%      68.000000                  13.000000    11323.000000
# max     249.000000                  43.000000   649263.000000
#
#        TCP_CONVERSATION_EXCHANGE  DIST_REMOTE_TCP_PORT   REMOTE_IPS  \
# count                1781.000000           1781.000000  1781.000000
# mean                   16.261089              5.472768     3.060640
# std                    40.500975             21.807327     3.386975
# min                     0.000000              0.000000     0.000000
# ...

# %%
# Count values in the target column (usually 'Type' for malicious vs benign)
websites['Type'].value_counts()
# Out:
# Type
# 0    1565
# 1     216
# Name: count, dtype: int64

# %%
# Show which columns are categorical (object type)
websites.select_dtypes(include='object').columns
# Out:
# Index(['URL', 'CHARSET', 'SERVER', 'WHOIS_COUNTRY', 'WHOIS_STATEPRO',
#        'WHOIS_REGDATE', 'WHOIS_UPDATED_DATE'],
#       dtype='object')

# %%
# Count how many missing values each column has
websites.isnull().sum()
# Out:
# URL                            0
# URL_LENGTH                     0
# NUMBER_SPECIAL_CHARACTERS      0
# CHARSET                        7
# SERVER                       176
# CONTENT_LENGTH               812
# WHOIS_COUNTRY                306
# WHOIS_STATEPRO               362
# WHOIS_REGDATE                127
# WHOIS_UPDATED_DATE           139
# TCP_CONVERSATION_EXCHANGE      0
# DIST_REMOTE_TCP_PORT           0
# REMOTE_IPS                     0
# APP_BYTES                      0
# SOURCE_APP_PACKETS             0
# REMOTE_APP_PACKETS             0
# SOURCE_APP_BYTES               0
# REMOTE_APP_BYTES               0
# APP_PACKETS                    0
# DNS_QUERY_TIMES                1
# Type                           0
# dtype: int64

# %%
# Conclusions after exploring the dataset overview:

# 1. The dataset contains 1781 websites and 21 columns.

# 2. The target column is 'Type':
#    - Value 0 = Benign website (1565 cases)
#    - Value 1 = Malicious website (216 cases)

# 3. There are 7 categorical (object-type) columns:
#    'URL', 'CHARSET', 'SERVER', 'WHOIS_COUNTRY',
#    'WHOIS_STATEPRO', 'WHOIS_REGDATE', 'WHOIS_UPDATED_DATE'

# 4. Some columns have missing values:
#    - 'SERVER': 176 missing
#    - 'CONTENT_LENGTH': 812 missing (almost 46% of rows)
#    - 'WHOIS_COUNTRY': 306 missing
#    - 'WHOIS_STATEPRO': 470 missing
#    - 'WHOIS_REGDATE': 127 missing
#    - 'WHOIS_UPDATED_DATE': 153 missing

# 5. The column 'URL' is a full website address (text), so it's not useful for modeling and should be dropped.

# 6. The column 'CONTENT_LENGTH' has too many missing values, and may not be worth keeping in the model.

# %% [markdown]
# #### Next, evaluate if the columns in this dataset are strongly correlated.
#
# If our dataset has strongly correlated columns, we need to choose certain ML algorithms instead of others. We need to evaluate this for our dataset now.
#
# Luckily, most of the columns in this dataset are ordinal which makes things a lot easier for us. In the next cells below, evaluate the level of collinearity of the data.
#
# We provide some general directions for you to consult in order to complete this step:
#
# 1. You will create a correlation matrix using the numeric columns in the dataset.
#
# 1. Create a heatmap using `seaborn` to visualize which columns have high collinearity.
#
# 1. Comment on which columns you might need to remove due to high collinearity.

# %%
# Import seaborn and matplotlib for plotting
import seaborn as sns
import matplotlib.pyplot as plt

# Create a correlation matrix of all numeric columns
correlation_matrix = websites.corr(numeric_only=True)

# Plot the heatmap to see which columns are strongly correlated
plt.figure(figsize=(16, 12))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Correlation Matrix of Numeric Features")
plt.show()

# %%
# Observations on multicollinearity:


# The target column 'Type' is numeric (int64) but it's actually a binary label:
# 0 = benign website, 1 = malicious website.
# It should be used only as the target variable, not as a feature.

# The correlation heatmap shows that some numeric features are strongly correlated:
# - 'APP_PACKETS' is almost identical to 'REMOTE_APP_PACKETS' and 'SOURCE_APP_PACKETS'
# - 'SOURCE_APP_PACKETS' and 'REMOTE_APP_PACKETS' have a correlation of 0.99
# - 'APP_BYTES' and 'SOURCE_APP_BYTES' are also highly correlated (~0.87)

# %% [markdown]
# # Challenge 2 - Remove Column Collinearity.
#
# From the heatmap you created, you should have seen at least 3 columns that can be removed due to high collinearity. Remove these columns from the dataset.
#
# Note that you should remove as few columns as you can. You don't have to remove all the columns at once. But instead, try removing one column, then produce the heatmap again to determine if additional columns should be removed. As long as the dataset no longer contains columns that are correlated for over 90%, you can stop. Also, keep in mind when two columns have high collinearity, you only need to remove one of them but not both.
#
# In the cells below, remove as few columns as you can to eliminate the high collinearity in the dataset. Make sure to comment on your way so that the instructional team can learn about your thinking process which allows them to give feedback. At the end, print the heatmap again.

# %%
# Drop the columns that are highly correlated with others: we remove only one column per correlated pair to keep the dataset informative

# 'APP_PACKETS' is almost identical to 'REMOTE_APP_PACKETS'
# 'SOURCE_APP_PACKETS' is highly correlated with 'REMOTE_APP_PACKETS'. We keep 'REMOTE_APP_PACKETS' and drop the others
# We also drop 'APP_BYTES' and keep 'SOURCE_APP_BYTES' to reduce redundancy

websites = websites.drop(['APP_PACKETS', 'SOURCE_APP_PACKETS', 'APP_BYTES'], axis=1)

# %%
# We removed the following columns:
# - 'APP_PACKETS': too similar to 'REMOTE_APP_PACKETS'
# - 'SOURCE_APP_PACKETS': also very similar to 'REMOTE_APP_PACKETS'
# - 'APP_BYTES': highly correlated with 'SOURCE_APP_BYTES'

# We kept only one column from each highly correlated group. This helps reduce multicollinearity and keeps the dataset simpler

# %%
# Print the heatmap again to make sure high collinearity is gone

plt.figure(figsize=(16, 12))
sns.heatmap(websites.corr(numeric_only=True), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Updated Correlation Matrix after Removing Highly Correlated Columns")
plt.show()

# %%
# The updated heatmap shows that no strong correlations remain (> 0.9), so the dataset is now ready for modeling without multicollinearity issues.

# %% [markdown]
# # Challenge 3 - Handle Missing Values
#
# The next step would be handling missing values. **We start by examining the number of missing values in each column, which you will do in the next cell.**

# %%
# Check how many missing values are in each column
websites.isnull().sum()
# Out:
# URL                            0
# URL_LENGTH                     0
# NUMBER_SPECIAL_CHARACTERS      0
# CHARSET                        7
# SERVER                       176
# CONTENT_LENGTH               812
# WHOIS_COUNTRY                306
# WHOIS_STATEPRO               362
# WHOIS_REGDATE                127
# WHOIS_UPDATED_DATE           139
# TCP_CONVERSATION_EXCHANGE      0
# DIST_REMOTE_TCP_PORT           0
# REMOTE_IPS                     0
# REMOTE_APP_PACKETS             0
# SOURCE_APP_BYTES               0
# REMOTE_APP_BYTES               0
# DNS_QUERY_TIMES                1
# Type                           0
# dtype: int64

# %% [markdown]
# If you remember in the previous labs, we drop a column if the column contains a high proportion of missing values. After dropping those problematic columns, we drop the rows with missing values.
#
# #### In the cells below, handle the missing values from the dataset. Remember to comment the rationale of your decisions.

# %%
# Drop 'CONTENT_LENGTH' because it has too many missing values (~45%)
websites = websites.drop('CONTENT_LENGTH', axis=1)

# Drop the one row where the target column 'Type' is missing
websites = websites.dropna(subset=['Type'])

# Fill missing values only in object (categorical) columns with 'Unknown'
object_cols = websites.select_dtypes(include='object').columns
websites[object_cols] = websites[object_cols].fillna('Unknown')

# %%
# I dropped 'CONTENT_LENGTH' because it had a high proportion of missing values.
# I also dropped the row where 'Type' was missing, since it's the target variable.
# All other missing values were filled with 'Unknown', which is a simple and safe strategy for categorical features.

# %% [markdown]
# #### Again, examine the number of missing values in each column.
#
# If all cleaned, proceed. Otherwise, go back and do more cleaning.

# %%
# Check again for missing values to make sure everything is handled
websites.isnull().sum()
# Out:
# URL                          0
# URL_LENGTH                   0
# NUMBER_SPECIAL_CHARACTERS    0
# CHARSET                      0
# SERVER                       0
# WHOIS_COUNTRY                0
# WHOIS_STATEPRO               0
# WHOIS_REGDATE                0
# WHOIS_UPDATED_DATE           0
# TCP_CONVERSATION_EXCHANGE    0
# DIST_REMOTE_TCP_PORT         0
# REMOTE_IPS                   0
# REMOTE_APP_PACKETS           0
# SOURCE_APP_BYTES             0
# REMOTE_APP_BYTES             0
# DNS_QUERY_TIMES              1
# Type                         0
# dtype: int64

# %%
# Fill the one remaining NaN in DNS_QUERY_TIMES with the median
websites['DNS_QUERY_TIMES'] = websites['DNS_QUERY_TIMES'].fillna(websites['DNS_QUERY_TIMES'].median())

# Check again for missing values to make sure everything is handled
websites.isnull().sum()
# Out:
# URL                          0
# URL_LENGTH                   0
# NUMBER_SPECIAL_CHARACTERS    0
# CHARSET                      0
# SERVER                       0
# WHOIS_COUNTRY                0
# WHOIS_STATEPRO               0
# WHOIS_REGDATE                0
# WHOIS_UPDATED_DATE           0
# TCP_CONVERSATION_EXCHANGE    0
# DIST_REMOTE_TCP_PORT         0
# REMOTE_IPS                   0
# REMOTE_APP_PACKETS           0
# SOURCE_APP_BYTES             0
# REMOTE_APP_BYTES             0
# DNS_QUERY_TIMES              0
# Type                         0
# dtype: int64

# %% [markdown]
# # Challenge 4 - Handle `WHOIS_*` Categorical Data

# %% [markdown]
# There are several categorical columns we need to handle. These columns are:
#
# * `URL`
# * `CHARSET`
# * `SERVER`
# * `WHOIS_COUNTRY`
# * `WHOIS_STATEPRO`
# * `WHOIS_REGDATE`
# * `WHOIS_UPDATED_DATE`
#
# How to handle string columns is always case by case. Let's start by working on `WHOIS_COUNTRY`. Your steps are:
#
# 1. List out the unique values of `WHOIS_COUNTRY`.
# 1. Consolidate the country values with consistent country codes. For example, the following values refer to the same country and should use consistent country code:
#     * `CY` and `Cyprus`
#     * `US` and `us`
#     * `SE` and `se`
#     * `GB`, `United Kingdom`, and `[u'GB'; u'UK']`
#
# #### In the cells below, fix the country values as intructed above.

# %%
# Show all unique values in WHOIS_COUNTRY to see what's messy
websites['WHOIS_COUNTRY'].unique()
# Out:
# array(['Unknown', 'US', 'SC', 'GB', 'UK', 'RU', 'AU', 'CA', 'PA', 'se',
#        'IN', 'LU', 'TH', "[u'GB'; u'UK']", 'FR', 'NL', 'UG', 'JP', 'CN',
#        'SE', 'SI', 'IL', 'ru', 'KY', 'AT', 'CZ', 'PH', 'BE', 'NO', 'TR',
#        'LV', 'DE', 'ES', 'BR', 'us', 'KR', 'HK', 'UA', 'CH',
#        'United Kingdom', 'BS', 'PK', 'IT', 'Cyprus', 'BY', 'AE', 'IE',
#        'UY', 'KG'], dtype=object)

# %%
# Convert all to uppercase for consistency
websites['WHOIS_COUNTRY'] = websites['WHOIS_COUNTRY'].str.upper()

# Replace variants with standardized country codes
websites['WHOIS_COUNTRY'] = websites['WHOIS_COUNTRY'].replace({
    "[U'GB'; U'UK']": 'UK',
    'UNITED KINGDOM': 'UK',
    'GB': 'UK',
    'U.K.': 'UK',
    
    'UNITED STATES': 'US',
    'U.S.': 'US',
    'USA': 'US',
    
    'CYPRUS': 'CY'
})

# Check unique values again
websites['WHOIS_COUNTRY'].unique()
# Out:
# array(['UNKNOWN', 'US', 'SC', 'UK', 'RU', 'AU', 'CA', 'PA', 'SE', 'IN',
#        'LU', 'TH', 'FR', 'NL', 'UG', 'JP', 'CN', 'SI', 'IL', 'KY', 'AT',
#        'CZ', 'PH', 'BE', 'NO', 'TR', 'LV', 'DE', 'ES', 'BR', 'KR', 'HK',
#        'UA', 'CH', 'BS', 'PK', 'IT', 'CY', 'BY', 'AE', 'IE', 'UY', 'KG'],
#       dtype=object)

# %% [markdown]
# Since we have fixed the country values, can we convert this column to ordinal now?
#
# Not yet. If you reflect on the previous labs how we handle categorical columns, you probably remember we ended up dropping a lot of those columns because there are too many unique values. Too many unique values in a column is not desirable in machine learning because it makes prediction inaccurate. But there are workarounds under certain conditions. One of the fixable conditions is:
#
# #### If a limited number of values account for the majority of data, we can retain these top values and re-label all other rare values.
#
# The `WHOIS_COUNTRY` column happens to be this case. You can verify it by print a bar chart of the `value_counts` in the next cell to verify:

# %%
# Show a bar chart of the top 20 WHOIS_COUNTRY values
websites['WHOIS_COUNTRY'].value_counts().head(20).plot(kind='bar', figsize=(12, 6), title='Top WHOIS_COUNTRY values')
# Out:
# <Axes: title={'center': 'Top WHOIS_COUNTRY values'}, xlabel='WHOIS_COUNTRY'>

# %% [markdown]
# #### After verifying, now let's keep the top 10 values of the column and re-label other columns with `OTHER`.

# %%
# Get the 10 most frequent countries
top_10_countries = websites['WHOIS_COUNTRY'].value_counts().head(10).index

# Replace all other countries with 'OTHER'
websites['WHOIS_COUNTRY'] = websites['WHOIS_COUNTRY'].apply(lambda x: x if x in top_10_countries else 'OTHER')

# %% [markdown]
# Now since `WHOIS_COUNTRY` has been re-labelled, we don't need `WHOIS_STATEPRO` any more because the values of the states or provinces may not be relevant any more. We'll drop this column.
#
# In addition, we will also drop `WHOIS_REGDATE` and `WHOIS_UPDATED_DATE`. These are the registration and update dates of the website domains. Not of our concerns.
#
# #### In the next cell, drop `['WHOIS_STATEPRO', 'WHOIS_REGDATE', 'WHOIS_UPDATED_DATE']`.

# %%
# Drop columns that are no longer useful for the analysis
websites = websites.drop(['WHOIS_STATEPRO', 'WHOIS_REGDATE', 'WHOIS_UPDATED_DATE'], axis=1)

# %% [markdown]
# # Challenge 5 - Handle Remaining Categorical Data & Convert to Ordinal
#
# Now print the `dtypes` of the data again. Besides `WHOIS_COUNTRY` which we already fixed, there should be 3 categorical columns left: `URL`, `CHARSET`, and `SERVER`.

# %%
# Show data types to confirm which columns are still categorical
websites.dtypes
# Out:
# URL                           object
# URL_LENGTH                     int64
# NUMBER_SPECIAL_CHARACTERS      int64
# CHARSET                       object
# SERVER                        object
# WHOIS_COUNTRY                 object
# TCP_CONVERSATION_EXCHANGE      int64
# DIST_REMOTE_TCP_PORT           int64
# REMOTE_IPS                     int64
# REMOTE_APP_PACKETS             int64
# SOURCE_APP_BYTES               int64
# REMOTE_APP_BYTES               int64
# DNS_QUERY_TIMES              float64
# Type                           int64
# dtype: object

# %% [markdown]
# #### `URL` is easy. We'll simply drop it because it has too many unique values that there's no way for us to consolidate.

# %%
# Drop the URL column because it has too many unique values
websites = websites.drop('URL', axis=1)

# %% [markdown]
# #### Print the unique value counts of `CHARSET`. You see there are only a few unique values. So we can keep it as it is.

# %%
# Show the unique values in CHARSET
websites['CHARSET'].value_counts()
# Out:
# CHARSET
# UTF-8           676
# ISO-8859-1      427
# utf-8           379
# us-ascii        155
# iso-8859-1      134
# Unknown           7
# windows-1251      1
# ISO-8859          1
# windows-1252      1
# Name: count, dtype: int64

# %%
# Normalize CHARSET values (lowercase)
websites['CHARSET'] = websites['CHARSET'].str.lower()

# Group similar or uncommon values
websites['CHARSET'] = websites['CHARSET'].replace({
    'utf8': 'utf-8',
    'iso8859-1': 'iso-8859-1',
    'iso-8859': 'iso-8859-1',
    'windows-1251': 'other',
    'windows-1252': 'other',
    'unknown': 'unknown',
    'us-ascii': 'us-ascii'
})

# %%
# Check cleaned CHARSET values
websites['CHARSET'].value_counts()
# Out:
# CHARSET
# utf-8         1055
# iso-8859-1     562
# us-ascii       155
# unknown          7
# other            2
# Name: count, dtype: int64

# %% [markdown]
# `SERVER` is a little more complicated. Print its unique values and think about how you can consolidate those values.
#
# #### Before you think of your own solution, don't read the instructions that come next.

# %%
# Show all unique SERVER values (before simplification)
websites['SERVER'].value_counts()
# Out:
# SERVER
# Apache                                                           386
# nginx                                                            211
# Unknown                                                          176
# Microsoft-HTTPAPI/2.0                                            113
# cloudflare-nginx                                                  94
#                                                                 ...
# My Arse                                                            1
# IdeaWebServer/v0.80                                                1
# Apache/2.4.17 (Unix) OpenSSL/1.0.1e-fips PHP/5.6.19                1
# Microsoft-IIS/7.5; litigation_essentials.lexisnexis.com  9999      1
# Apache/2.2.16 (Debian)                                             1
# Name: count, Length: 239, dtype: int64

# %% [markdown]
# ![Think Hard](../images/think-hard.jpg)

# %%
# After inspecting the SERVER column, we notice that although it has 239 unique values, many of them are simply different versions or formats of a few major server types.
# To simplify the data, we will group all servers that contain the words: 'apache', 'microsoft', or 'nginx' (case-insensitive) into their respective categories.
# Everything else will be labeled as 'Other'.

# %% [markdown]
# Although there are so many unique values in the `SERVER` column, there are actually only 3 main server types: `Microsoft`, `Apache`, and `nginx`. Just check if each `SERVER` value contains any of those server types and re-label them. For `SERVER` values that don't contain any of those substrings, label with `Other`.
#
# At the end, your `SERVER` column should only contain 4 unique values: `Microsoft`, `Apache`, `nginx`, and `Other`.

# %%
# Convert all SERVER values to lowercase to ensure consistent string matching
websites['SERVER'] = websites['SERVER'].str.lower()

# Define a function to categorize server types
def classify_server(value):
    if 'microsoft' in value:
        return 'Microsoft'
    elif 'apache' in value:
        return 'Apache'
    elif 'nginx' in value:
        return 'nginx'
    else:
        return 'Other'

# Apply the function to the SERVER column
websites['SERVER'] = websites['SERVER'].apply(classify_server)

# %%
# Show the final value counts after simplification
websites['SERVER'].value_counts()
# Out:
# SERVER
# Apache       643
# Other        504
# nginx        436
# Microsoft    198
# Name: count, dtype: int64

# %% [markdown]
# OK, all our categorical data are fixed now. **Let's convert them to ordinal data using Pandas' `get_dummies` function ([documentation](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.get_dummies.html)). Also, assign the data with dummy values to a new variable `website_dummy`.**

# %%
# pd.get_dummies() creates a new binary (0/1) column for each category. For example, if SERVER has values ['Apache', 'nginx', 'Microsoft', 'Other'], it will create new columns like SERVER_Apache, SERVER_nginx, etc.

# We assign the transformed dataset to a new variable called website_dummy
website_dummy = pd.get_dummies(websites)

# %% [markdown]
# Now, inspect `website_dummy` to make sure the data and types are intended - there shouldn't be any categorical columns at this point.

# %%
# Let's inspect the new DataFrame to confirm that all columns are now numerical and no object (categorical) types remain

# .info() shows column types and non-null counts
website_dummy.info()

# Optionally, display the first few rows to check the structure
website_dummy.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1781 entries, 0 to 1780
# Data columns (total 30 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   URL_LENGTH                 1781 non-null   int64
#  1   NUMBER_SPECIAL_CHARACTERS  1781 non-null   int64
#  2   TCP_CONVERSATION_EXCHANGE  1781 non-null   int64
#  3   DIST_REMOTE_TCP_PORT       1781 non-null   int64
#  4   REMOTE_IPS                 1781 non-null   int64
#  5   REMOTE_APP_PACKETS         1781 non-null   int64
#  6   SOURCE_APP_BYTES           1781 non-null   int64
#  7   REMOTE_APP_BYTES           1781 non-null   int64
#  8   DNS_QUERY_TIMES            1781 non-null   float64
#  9   Type                       1781 non-null   int64
#  10  CHARSET_iso-8859-1         1781 non-null   bool
#  11  CHARSET_other              1781 non-null   bool
#  12  CHARSET_unknown            1781 non-null   bool
# ...

# %% [markdown]
# # Challenge 6 - Modeling, Prediction, and Evaluation
#
# We'll start off this section by splitting the data to train and test. **Name your 4 variables `X_train`, `X_test`, `y_train`, and `y_test`. Select 80% of the data for training and 20% for testing.**

# %%
from sklearn.model_selection import train_test_split

# First, we separate the features (X) and the target variable (y)
X = website_dummy.drop('Type', axis=1)  # All columns except 'Type'
y = website_dummy['Type']              # The target column (0 = benign, 1 = malicious)

# Scale the features before splitting
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Now we split the data into training and testing sets (80% train, 20% test)
# We also use random_state=0 to make the results reproducible
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=0)

# %% [markdown]
# #### In this lab, we will try two different models and compare our results.
#
# The first model we will use in this lab is logistic regression. We have previously learned about logistic regression as a classification algorithm. In the cell below, load `LogisticRegression` from scikit-learn and initialize the model.

# %%
# Import the LogisticRegression model from scikit-learn
from sklearn.linear_model import LogisticRegression

# Initialize the logistic regression model
log_model = LogisticRegression(max_iter=1000, random_state=0)

# %% [markdown]
# Next, fit the model to our training data. We have already separated our data into 4 parts. Use those in your model.

# %%
# Fit (train) the model on the training data
log_model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=0)

# %% [markdown]
# finally, import `confusion_matrix` and `accuracy_score` from `sklearn.metrics` and fit our testing data. Assign the fitted data to `y_pred` and print the confusion matrix as well as the accuracy score

# %%
# Import metrics to evaluate the model
from sklearn.metrics import confusion_matrix, accuracy_score

# Use the model to predict the labels for the test set
y_pred = log_model.predict(X_test)

# Print the confusion matrix
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))

# Print the accuracy score
print("\nAccuracy Score:")
print(accuracy_score(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[311   5]
#  [ 23  18]]
#
# Accuracy Score:
# 0.9215686274509803

# %% [markdown]
# What are your thoughts on the performance of the model? Write your conclusions below.

# %%
# The logistic regression model achieved an accuracy of approximately 92%.
# From the confusion matrix, we see it correctly predicted:
# - 311 benign websites (True Negatives)
# - 18 malicious websites (True Positives)
# However, it misclassified:
# - 5 benign websites as malicious (False Positives)
# - 23 malicious websites as benign (False Negatives)
# This means that although the overall performance is good, the model is more likely to miss some malicious websites than to falsely flag a benign one.

# %% [markdown]
# #### Our second algorithm is is K-Nearest Neighbors.
#
# Though is it not required, we will fit a model using the training data and then test the performance of the model using the testing data. Start by loading `KNeighborsClassifier` from scikit-learn and then initializing and fitting the model. We'll start off with a model where k=3.

# %%
# Import the KNN model
from sklearn.neighbors import KNeighborsClassifier

# Initialize the model with k=3
knn_model = KNeighborsClassifier(n_neighbors=3)

# Fit (train) the model
knn_model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# To test your model, compute the predicted values for the testing sample and print the confusion matrix as well as the accuracy score.

# %%
# Import metrics
from sklearn.metrics import confusion_matrix, accuracy_score

# Predict test data
y_pred_knn = knn_model.predict(X_test)

# Print confusion matrix
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred_knn))

# Print accuracy
print("\nAccuracy Score:")
print(accuracy_score(y_test, y_pred_knn))
# Out:
# Confusion Matrix:
# [[302  14]
#  [  9  32]]
#
# Accuracy Score:
# 0.9355742296918768

# %%
# The KNN model with k=3 achieved an accuracy of approximately 93.56%.
# According to the confusion matrix:
# - 302 benign websites were correctly classified (true negatives).
# - 32 malicious websites were correctly identified (true positives).
# - 14 benign websites were incorrectly flagged as malicious (false positives).
# - 9 malicious websites were missed (false negatives).

# Compared to the logistic regression model (accuracy ≈ 92.16%), KNN performed slightly better.

# %% [markdown]
# #### We'll create another K-Nearest Neighbors model with k=5.
#
# Initialize and fit the model below and print the confusion matrix and the accuracy score.

# %%
# Import the classifier
from sklearn.neighbors import KNeighborsClassifier

# Initialize the KNN model with k = 5
knn_model_5 = KNeighborsClassifier(n_neighbors=5)

# Fit the model with the training data
knn_model_5.fit(X_train, y_train)

# Predict on test set
y_pred_knn_5 = knn_model_5.predict(X_test)

# Evaluate the model
from sklearn.metrics import confusion_matrix, accuracy_score
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred_knn_5))

print("\nAccuracy Score:")
print(accuracy_score(y_test, y_pred_knn_5))
# Out:
# Confusion Matrix:
# [[301  15]
#  [ 11  30]]
#
# Accuracy Score:
# 0.927170868347339

# %% [markdown]
# Did you see an improvement in the confusion matrix when increasing k to 5? Did you see an improvement in the accuracy score? Write your conclusions below.

# %%
# The KNN model with k=5 achieved an accuracy of approximately 92.72%.
# Compared to k=3 (accuracy ≈ 93.56%), the performance slightly decreased.
# According to the confusion matrix:
# - More benign websites were incorrectly classified as malicious (false positives).
# - More malicious websites were missed (false negatives).
# Overall, increasing k from 3 to 5 did not improve the model performance in this case.

# %% [markdown]
# # Bonus Challenge - Feature Scaling
#
# Problem-solving in machine learning is iterative. You can improve your model prediction with various techniques (there is a sweetspot for the time you spend and the improvement you receive though). Now you've completed only one iteration of ML analysis. There are more iterations you can conduct to make improvements. In order to be able to do that, you will need deeper knowledge in statistics and master more data analysis techniques. In this bootcamp, we don't have time to achieve that advanced goal. But you will make constant efforts after the bootcamp to eventually get there.
#
# However, now we do want you to learn one of the advanced techniques which is called *feature scaling*. The idea of feature scaling is to standardize/normalize the range of independent variables or features of the data. This can make the outliers more apparent so that you can remove them. This step needs to happen during Challenge 6 after you split the training and test data because you don't want to split the data again which makes it impossible to compare your results with and without feature scaling. For general concepts about feature scaling, click [here](https://en.wikipedia.org/wiki/Feature_scaling). To read deeper, click [here](https://medium.com/greyatom/why-how-and-when-to-scale-your-features-4b30ab09db5e).
#
# In the next cell, attempt to improve your model prediction accuracy by means of feature scaling. A library you can utilize is `sklearn.preprocessing.RobustScaler` ([documentation](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.RobustScaler.html)). You'll use the `RobustScaler` to fit and transform your `X_train`, then transform `X_test`. You will use logistic regression to fit and predict your transformed data and obtain the accuracy score in the same way. Compare the accuracy score with your normalized data with the previous accuracy data. Is there an improvement?

# %%
# Import RobustScaler
from sklearn.preprocessing import RobustScaler

# Initialize the scaler
robust_scaler = RobustScaler()

# Fit and transform X_train
X_train_scaled = robust_scaler.fit_transform(X_train)

# Transform X_test (important: never fit on test data!)
X_test_scaled = robust_scaler.transform(X_test)

# %%
# Import and initialize logistic regression
from sklearn.linear_model import LogisticRegression

log_model_robust = LogisticRegression(max_iter=1000, random_state=0)

# Fit the model on the scaled training data
log_model_robust.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=0)

# %%
# Import evaluation metrics
from sklearn.metrics import confusion_matrix, accuracy_score

# Predict on the scaled test set
y_pred_robust = log_model_robust.predict(X_test_scaled)

# Show confusion matrix
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred_robust))

# Show accuracy score
print("\nAccuracy Score:")
print(accuracy_score(y_test, y_pred_robust))
# Out:
# Confusion Matrix:
# [[309   7]
#  [ 21  20]]
#
# Accuracy Score:
# 0.9215686274509803

# %%
# After applying both StandardScaler and RobustScaler, the final accuracy of the logistic regression model remained almost the same (~92.15%).
# With StandardScaler, the model predicted slightly fewer false positives (5 instead of 7), but also slightly more false negatives (23 instead of 21).
# RobustScaler improved the number of correctly predicted malicious websites (true positives: 20 vs 18), which may be important in security-related contexts.
# Overall, both scalers led to very similar performance in this case.
